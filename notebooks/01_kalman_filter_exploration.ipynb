# %% [markdown]
# # Exploración del Filtro de Kalman
#
# Ajustar process_noise / measurement_noise antes de fijarlos en `config/config.yaml`.
# Generar una trayectoria sintética con ruido conocido y comparar contra la salida filtrada.

# %%
import numpy as np
import matplotlib.pyplot as plt
